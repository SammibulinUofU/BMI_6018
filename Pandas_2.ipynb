# %% [markdown]
# ## Pandas Assignment Part 2
# **Melt, Pivot, Aggregation, Iteration, Groupby**

# %%
import pandas as pd

# %%
# Loading in Diabetes Dataset #
raw_data = pd.read_csv("diabetic_data.csv", header = 0)
print(raw_data.shape)
raw_data.head()
# Out:
# (101766, 50)
#    encounter_id  patient_nbr             race  gender      age weight  \
# 0       2278392      8222157        Caucasian  Female   [0-10)      ?
# 1        149190     55629189        Caucasian  Female  [10-20)      ?
# 2         64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3        500364     82442376        Caucasian    Male  [30-40)      ?
# 4         16680     42519267        Caucasian    Male  [40-50)      ?
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# 1                  1                         1                    7
# 2                  1                         1                    7
# 3                  1                         1                    7
# 4                  1                         1                    7
#
#    time_in_hospital  ... citoglipton insulin  glyburide-metformin  \
# 0                 1  ...          No      No                   No
# 1                 3  ...          No      Up                   No
# 2                 2  ...          No      No                   No
# 3                 2  ...          No      Up                   No
# 4                 1  ...          No  Steady                   No
#
#    glipizide-metformin  glimepiride-pioglitazone  metformin-rosiglitazone  \
# 0                   No                        No                       No
# 1                   No                        No                       No
# 2                   No                        No                       No
# 3                   No                        No                       No
# 4                   No                        No                       No
#
#    metformin-pioglitazone  change diabetesMed readmitted
# 0                      No      No          No         NO
# 1                      No      Ch         Yes        >30
# 2                      No      No         Yes         NO
# 3                      No      Ch         Yes         NO
# 4                      No      Ch         Yes         NO
#
# [5 rows x 50 columns]

# %% [markdown]
# #### GroupBy
# Group DataFrame using a mapper or by a Series of columns.
#
# #### Aggregate
# Perform one or more operations on data based on specified axis

# %%
# Compare the time spent in hospital between genders
# Check the values within the raw_data gender column
print(raw_data['gender'].value_counts())

# Filter for Male and Female and check for their removal in filt_data
filt_data = raw_data[raw_data['gender'].isin(["Male", "Female"])]
print(filt_data['gender'].value_counts())

# Group the data by the gender value and find the mean time spent in hospital
gender_mean = filt_data.groupby("gender").time_in_hospital.agg("mean")
gender_mean
# Out:
# gender
# Female             54708
# Male               47055
# Unknown/Invalid        3
# Name: count, dtype: int64
# gender
# Female    54708
# Male      47055
# Name: count, dtype: int64
# gender
# Female    4.478797
# Male      4.299777
# Name: time_in_hospital, dtype: float64

# %% [markdown]
# #### Pivot
# Produce a pivot table based on column values
# - take one column and transition it into multiple

# %%
# Pivot Table
# Determine average time spent in hospital for various admission types
# Grab necessary columns
pivot_table = raw_data[['encounter_id', "patient_nbr","admission_type_id", "time_in_hospital"]]
# Create a pivot table
# Index will be the encounter ID with the columns being the admission type ID and values being the time spent in hospital
# Take the mean of each column
pivot_table = pivot_table.pivot(index = "encounter_id", columns = "admission_type_id", values = "time_in_hospital")

pivot_table.mean()
# Out:
# admission_type_id
# 1    4.378274
# 2    4.610714
# 3    4.320473
# 4    3.200000
# 5    3.947126
# 6    4.583066
# 7    4.857143
# 8    3.062500
# dtype: float64

# %% [markdown]
# #### Melt
# Transition a data frame from wide to long format
# - One column contains observation identifiers
# - The remaining columns contain measured observations

# %%
# Reshaping the patient number and insulin column
pre_melt = raw_data[['patient_nbr', 'insulin']]
# the patient number is the id variable
post_melt = pre_melt.melt(id_vars = "patient_nbr", value_vars="insulin", value_name="insulin_status")
post_melt
# Out:
#         patient_nbr variable insulin_status
# 0           8222157  insulin             No
# 1          55629189  insulin             Up
# 2          86047875  insulin             No
# 3          82442376  insulin             Up
# 4          42519267  insulin         Steady
# ...             ...      ...            ...
# 101761    100162476  insulin           Down
# 101762     74694222  insulin         Steady
# 101763     41088789  insulin           Down
# 101764     31693671  insulin             Up
# 101765    175429310  insulin             No
#
# [101766 rows x 3 columns]

# %% [markdown]
# #### Iter
# iterrows() returns the iterator yielding each index value along with a series containing the data in each row.

# %%
# Creating a dictionary of insulin values for each patient
# key = patient number, value = list of insulin values

insulin_tracker = {}

for row_index,row in post_melt.iterrows():
    if row[0] in insulin_tracker.keys():
      insulin_tracker[row[0]].append(row[2])
    else:
      insulin_tracker[row[0]] = [row[2]]

insulin_tracker
# Out:
# /tmp/ipykernel_1113/3799072883.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] in insulin_tracker.keys():
# /tmp/ipykernel_1113/3799072883.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   insulin_tracker[row[0]] = [row[2]]
# /tmp/ipykernel_1113/3799072883.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   insulin_tracker[row[0]].append(row[2])
# {8222157: ['No'],
#  55629189: ['Up'],
#  86047875: ['No'],
#  82442376: ['Up'],
#  42519267: ['Steady'],
#  82637451: ['Steady'],
#  84259809: ['Steady'],
#  114882984: ['No'],
#  48330783: ['Steady'],
#  63555939: ['Steady'],
#  89869032: ['Steady'],
#  77391171: ['Steady'],
#  85504905: ['Down', 'Steady'],
#  77586282: ['Steady'],
#  49726791: ['Steady'],
#  86328819: ['Up'],
#  92519352: ['Steady'],
#  108662661: ['No'],
#  107389323: ['Steady'],
#  69422211: ['Steady'],
#  22864131: ['Down'],
#  21239181: ['Steady'],
#  63000108: ['No'],
#  107400762: ['No'],
#  62718876: ['Steady'],
#  21861756: ['No'],
#  40523301: ['No'],
#  115196778: ['Steady', 'Down', 'Steady', 'Steady', 'Steady'],
#  41606064: ['Down', 'Steady', 'Steady'],
#  18196434: ['No'],
#  56480238: ['Steady'],
#  96664626: ['Down'],
#  80845353: ['Steady', 'Down', 'No'],
#  114715242: ['Steady', 'Down'],
#  3327282: ['Down'],
#  63023292: ['Down', 'Steady', 'Steady'],
#  98427861: ['Steady'],
#  112002975: ['Steady', 'Steady'],
#  101002446: ['Steady'],
#  104672268: ['Steady'],
#  80588529: ['Down'],
#  99715041: ['Steady'],
#  96435585: ['Steady'],
#  66274866: ['Steady', 'No'],
#  80177094: ['Steady'],
#  106936875: ['Steady'],
#  86240259: ['Down', 'Up'],
#  51838164: ['Steady'],
#  90097839: ['Up'],
#  34997814: ['Steady'],
#  21820806: ['No', 'No'],
#  72200358: ['Steady'],
#  37746639: ['Steady'],
#  58497651: ['Down'],
#  113848434: ['Down'],
#  17928900: ['Down'],
#  93232917: ['Steady'],
#  3146373: ['Down'],
#  56714769: ['Down'],
#  71778564: ['Down'],
#  63754317: ['Steady', 'Steady'],
#  94994802: ['Down'],
#  64729746: ['Up'],
#  24370299: ['Steady'],
#  110537262: ['Down'],
#  58231314: ['Steady'],
#  3376278: ['Up'],
#  83775519: ['Steady'],
#  23043240: ['Steady', 'Steady', 'Steady'],
#  74447460: ['Steady'],
#  95075649: ['No'],
#  55152216: ['Up', 'Down'],
#  22655295: ['Steady'],
#  60679647: ['Down'],
#  93196251: ['Up'],
#  105366150: ['No', 'No'],
#  106469577: ['No'],
#  100113975: ['Up'],
#  34806888: ['Up'],
#  114039603: ['Steady'],
#  101707335: ['Up', 'Up'],
#  96190083: ['Down'],
#  76197258: ['Down'],
#  68661747: ['No'],
#  64494171: ['Down'],
#  73921680: ['No'],
#  57857994: ['Down'],
#  91181331: ['No'],
#  20830941: ['Steady'],
#  54746082: ['Steady', 'Steady'],
#  91370916: ['Steady'],
#  101334321: ['Steady'],
#  22997880: ['Steady', 'Steady'],
#  79549353: ['Steady'],
#  106343838: ['Steady', 'Steady', 'Steady'],
#  84981816: ['Down'],
#  84488562: ['Up'],
#  92117574: ['Steady'],
#  38688588: ['Steady'],
#  91530936: ['Steady'],
#  50253120: ['No'],
#  67897251: ['Steady'],
#  71003736: ['Down'],
#  48925980: ['No'],
#  23807808: ['Up'],
#  96440301: ['No'],
#  105882957: ['Steady'],
#  76159881: ['Steady'],
#  72405540: ['Down', 'Steady'],
#  10777860: ['Steady'],
#  48131838: ['No'],
#  49407813: ['Steady'],
#  6915888: ['Up'],
#  10430154: ['Steady'],
#  3115566: ['Steady'],
#  720936: ['Down', 'Steady', 'Steady', 'Steady'],
#  661014: ['Down'],
#  15856002: ['Up'],
#  29754351: ['Down'],
#  1719279: ['No', 'Down', 'Steady', 'Down', 'Down', 'Steady', 'No'],
#  7919802: ['No'],
#  5041602: ['Down', 'Steady', 'Down'],
#  6500556: ['No'],
#  276606: ['Steady',
#   'Down',
#   'No',
#   'Up',
#   'Steady',
#   'Down',
#   'Steady',
#   'Down',
#   'Steady',
#   'Steady'],
#  815391: ['Steady'],
#  18030078: ['Steady'],
#  53612379: ['Down', 'Up'],
#  558360: ['No'],
#  58471101: ['Steady'],
#  6836652: ['Steady'],
#  427482: ['Up'],
#  44279478: ['No'],
#  7472070: ['No'],
#  53848278: ['No'],
#  5332491: ['Up', 'Steady'],
#  2519748: ['Down'],
#  5287950: ['Steady', 'No', 'No', 'No', 'No', 'Steady', 'No'],
#  2024739: ['Steady'],
#  2780676: ['Down'],
#  3635847: ['Down'],
#  77475465: ['Steady'],
#  95586993: ['No'],
#  100035: ['Steady'],
#  608841: ['Steady', 'Steady', 'Steady'],
#  1059561: ['No'],
#  966042: ['Steady'],
#  1741662: ['Up', 'Down', 'Steady'],
#  8147493: ['No'],
#  3377124: ['No'],
#  90460242: ['Up', 'Steady', 'Down'],
#  69318126: ['No'],
#  5074974: ['No'],
#  4311585: ['Steady', 'Steady'],
#  981198: ['Steady', 'Steady'],
#  720369: ['No', 'No'],
#  77574096: ['Steady'],
#  4279149: ['Steady'],
#  99378891: ['Steady'],
#  4136517: ['No'],
#  80499960: ['No'],
#  8354835: ['No'],
#  81644544: ['Down'],
#  384939: ['No',
#   'No',
#   'No',
#   'Steady',
#   'No',
#   'No',
#   'Steady',
#   'No',
#   'No',
#   'Steady',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No'],
#  708741: ['Down', 'Steady'],
#  101686554: ['Down'],
#  2038905: ['No'],
#  8348193: ['Steady'],
#  48452823: ['Up'],
#  3168720: ['No'],
#  88614963: ['Steady'],
#  688347: ['No', 'No'],
#  1784367: ['No', 'No'],
#  2604141: ['No', 'No'],
#  8005509: ['Steady'],
#  5039316: ['Steady'],
#  83864538: ['Steady'],
#  826470: ['No'],
#  112394736: ['No'],
#  794313: ['Steady'],
#  357300: ['No'],
#  105388416: ['Steady'],
#  1174005: ['No'],
#  1427400: ['No', 'No', 'No', 'No', 'No'],
#  6656679: ['No', 'No', 'No', 'Steady', 'No', 'Steady'],
#  2741004: ['Down'],
#  5281155: ['No'],
#  3163068: ['No'],
#  3151539: ['Steady'],
#  89193870: ['No'],
#  2498787: ['No'],
#  1451637: ['No', 'No'],
#  279009: ['Down', 'No'],
#  511965: ['Down'],
#  2283327: ['Up', 'No'],
#  6225435: ['No'],
#  100605564: ['No'],
#  716805: ['No'],
#  80156115: ['No'],
#  780975: ['No', 'No', 'Steady', 'No'],
#  8432703: ['No'],
#  3492477: ['Steady'],
#  3845322: ['Steady'],
#  2596824: ['No', 'Steady'],
#  4943709: ['Down'],
#  564732: ['No'],
#  1121121: ['Down', 'Down', 'No'],
#  87806799: ['Steady', 'Down'],
#  83363985: ['Steady'],
#  52897581: ['Down'],
#  6539481: ['No', 'No', 'No', 'No'],
#  3053970: ['Steady', 'Up', 'Steady'],
#  95326821: ['No'],
#  2359485: ['Steady'],
#  42470721: ['Up'],
#  93479463: ['Steady'],
#  5014656: ['Down', 'Steady'],
#  634689: ['Up', 'Up'],
#  2499588: ['Down'],
#  48573: ['No', 'No', 'No', 'Steady', 'No'],
#  105589584: ['No', 'No', 'No'],
#  3306681: ['Steady'],
#  1160226: ['Up', 'Steady', 'Steady', 'No', 'Steady'],
#  114304932: ['Up'],
#  8320608: ['No', 'No'],
#  492012: ['Down', 'No'],
#  2160585: ['No'],
#  91305: ['No'],
#  924174: ['Steady', 'Steady'],
#  107102214: ['Steady'],
#  499995: ['No'],
#  284400: ['Steady', 'Steady', 'No', 'No', 'Steady', 'No'],
#  63956250: ['No'],
#  4030317: ['No', 'No', 'No', 'Steady'],
#  580788: ['Steady', 'Down'],
#  2341521: ['No', 'Steady', 'Steady', 'Steady', 'Steady', 'No'],
#  3094443: ['No', 'No', 'No', 'No'],
#  108387207: ['No', 'No'],
#  8450352: ['Steady'],
#  6531597: ['Up'],
#  567018: ['Down', 'No', 'Steady', 'No', 'No'],
#  32409162: ['Down'],
#  794772: ['No'],
#  7926723: ['Down'],
#  87652710: ['Up'],
#  3782196: ['No'],
#  5073354: ['No'],
#  49453713: ['Up'],
#  109286217: ['Steady'],
#  369684: ['No', 'No', 'Steady', 'Down', 'Steady'],
#  86209290: ['Up'],
#  1119429: ['Steady'],
#  958194: ['No'],
#  1729764: ['Steady'],
#  1004859: ['Steady'],
#  5592591: ['Steady'],
#  5776821: ['Up'],
#  3762756: ['No'],
#  3436695: ['Down'],
#  105017130: ['Steady'],
#  3425292: ['No'],
#  22827528: ['Steady'],
#  15849: ['No'],
#  25434: ['Steady'],
#  277065: ['No', 'No', 'No', 'No', 'No'],
#  4845384: ['Steady'],
#  1660293: ['Steady',
#   'Steady',
#   'Down',
#   'Steady',
#   'Up',
#   'Down',
#   'Up',
#   'Steady',
#   'Up',
#   'Steady',
#   'Steady',
#   'Steady',
#   'Up',
#   'Up',
#   'Steady',
#   'Up',
#   'Steady',
#   'Down',
#   'Steady',
#   'Steady',
#   'Steady',
#   'Down',
#   'Up'],
#  8568180: ['Steady'],
#  1159830: ['Steady'],
#  1011627: ['Steady'],
#  15528213: ['Up'],
#  419832: ['Steady', 'Steady', 'Steady', 'Steady'],
#  1217313: ['No', 'No'],
#  795222: ['Down'],
#  539910: ['Steady'],
#  481788: ['No', 'Down', 'Up', 'Steady'],
#  4624767: ['Steady', 'No'],
#  541134: ['Up', 'Steady', 'Steady'],
#  4049325: ['No'],
#  8317971: ['Steady'],
#  3454722: ['Down'],
#  929223: ['Steady', 'Steady', 'No'],
#  42867: ['Down', 'Down'],
#  3323655: ['No'],
#  1421838: ['Steady', 'Up'],
#  430092: ['Steady', 'No', 'No', 'No', 'Steady'],
#  1802943: ['Down', 'No', 'Down', 'Steady'],
#  95564241: ['Steady'],
#  103892157: ['No'],
#  6609888: ['Steady'],
#  493038: ['Steady', 'No'],
#  5832918: ['Steady', 'Steady'],
#  23393484: ['No'],
#  82844478: ['Steady'],
#  78246: ['Steady'],
#  995562: ['No'],
#  818874: ['No'],
#  108453753: ['Steady'],
#  63285453: ['No'],
#  2486844: ['No',
#   'Down',
#   'No',
#   'Steady',
#   'Down',
#   'No',
#   'Steady',
#   'Steady',
#   'Steady',
#   'Down',
#   'No',
#   'Steady',
#   'Steady',
#   'Steady',
#   'Steady'],
#  638910: ['Up'],
#  81353088: ['Up', 'Down', 'Steady'],
#  2579337: ['Steady', 'Steady'],
#  5120595: ['Down'],
#  22856067: ['No'],
#  60789438: ['Steady'],
#  371538: ['No'],
#  2579427: ['No', 'Steady'],
#  1190160: ['No', 'Steady', 'Steady', 'Steady'],
#  1300581: ['No'],
#  669393: ['Steady', 'Down', 'Steady', 'No', 'No', 'No', 'No'],
#  8566578: ['No'],
#  476343: ['No'],
#  69921: ['No'],
#  12447: ['Steady', 'Down', 'No', 'Steady'],
#  3719655: ['No', 'No', 'Steady', 'No'],
#  3260223: ['No'],
#  969633: ['No'],
#  1251378: ['No'],
#  8649234: ['Steady'],
#  87963039: ['No'],
#  2906667: ['Steady'],
#  1423485: ['No'],
#  2940129: ['No', 'Steady'],
#  94582188: ['Down'],
#  76903839: ['Down', 'Steady'],
#  997209: ['Down', 'Steady'],
#  5075091: ['Steady'],
#  554472: ['Steady', 'Steady', 'Steady', 'Steady', 'Down', 'Down'],
#  4582233: ['Steady', 'Steady'],
#  442341: ['Up'],
#  3629394: ['Steady'],
#  6550191: ['No', 'No'],
#  2518758: ['No'],
#  71235666: ['No', 'No'],
#  5288760: ['No', 'Steady', 'No'],
#  99333783: ['Steady'],
#  3596877: ['Down', 'Steady', 'Down'],
#  1552221: ['No'],
#  1211985: ['No', 'No', 'Steady', 'No', 'Steady', 'Steady'],
#  581508: ['Down', 'Down'],
#  4798962: ['No'],
#  5161536: ['No'],
#  804132: ['No'],
#  1697409: ['No', 'No'],
#  1306215: ['Steady'],
#  2525661: ['Steady'],
#  4338342: ['No'],
#  2923146: ['No', 'Up', 'Steady', 'Up'],
#  491760: ['No', 'No', 'Steady', 'No', 'No', 'Steady'],
#  362610: ['Up',
#   'Down',
#   'No',
#   'Up',
#   'Down',
#   'Steady',
#   'Steady',
#   'No',
#   'Steady',
#   'Down',
#   'Steady',
#   'Down',
#   'No',
#   'No',
#   'Steady'],
#  2486277: ['No', 'No'],
#  113023935: ['Steady'],
#  3656088: ['No', 'No', 'No'],
#  4382343: ['No'],
#  5877477: ['No', 'Steady', 'Steady', 'Steady'],
#  980262: ['No'],
#  567279: ['Steady'],
#  53461359: ['Steady'],
#  4190778: ['Steady', 'Steady'],
#  47881611: ['Steady'],
#  4910139: ['Steady'],
#  1582326: ['Steady'],
#  1070181: ['Up'],
#  3292920: ['Steady'],
#  6325848: ['Steady', 'Down'],
#  1383318: ['Down'],
#  20295: ['Steady', 'Steady'],
#  90341199: ['Steady', 'No'],
#  338976: ['Steady', 'No'],
#  2789793: ['Down', 'Down'],
#  4937643: ['No', 'No', 'No'],
#  694908: ['Steady'],
#  25831539: ['No'],
#  73884501: ['Steady'],
#  7906419: ['Steady'],
#  1660932: ['Steady', 'Steady', 'No', 'Steady', 'Up', 'No', 'Up'],
#  34609950: ['Steady'],
#  81931626: ['Down'],
#  1090098: ['Steady'],
#  5505885: ['No', 'Down', 'Steady', 'No'],
#  8420310: ['No', 'No'],
#  68029074: ['No', 'Steady', 'No'],
#  654273: ['Steady', 'Up'],
#  3201255: ['Down'],
#  70110: ['Steady', 'Steady', 'No', 'Steady', 'No', 'Steady', 'Down'],
#  4029444: ['No', 'No', 'No', 'No'],
#  8879148: ['Steady'],
#  39393621: ['No'],
#  5990040: ['Steady', 'No'],
#  463932: ['Down', 'Steady', 'Steady', 'Steady'],
#  61873722: ['Steady'],
#  303957: ['No'],
#  4269735: ['Steady'],
#  516384: ['Down', 'Steady', 'Down'],
#  550674: ['Steady'],
#  1495962: ['Steady'],
#  5985369: ['No'],
#  29173437: ['Up'],
#  305793: ['No', 'No'],
#  1598274: ['No'],
#  28088019: ['Steady'],
#  78047901: ['Up'],
#  3667590: ['No'],
#  1162701: ['No', 'No', 'No'],
#  100533195: ['No', 'No'],
#  502200: ['Steady'],
#  693747: ['No', 'No'],
#  2798721: ['Down'],
#  1748268: ['No', 'No'],
#  24696: ['No'],
#  486162: ['Down', 'No'],
#  412038: ['Steady', 'Steady'],
#  5840127: ['Down', 'No', 'No'],
#  4856382: ['Steady', 'Steady', 'Down', 'Steady'],
#  8946090: ['No', 'No'],
#  109797327: ['Up'],
#  2524077: ['Steady'],
#  602604: ['No', 'Steady'],
#  8147232: ['Steady'],
#  96165: ['No', 'No'],
#  4893183: ['Down', 'Steady'],
#  3678201: ['Down'],
#  75338109: ['No'],
#  3280554: ['Steady'],
#  15051789: ['No'],
#  68310432: ['Steady'],
#  55426896: ['Steady'],
#  732303: ['Steady'],
#  3306321: ['No', 'Steady'],
#  78770403: ['No'],
#  6414021: ['No', 'Steady', 'Steady', 'Steady', 'No'],
#  55890810: ['Down'],
#  40158: ['Steady', 'Steady', 'Steady', 'Down', 'Up', 'Steady'],
#  34568172: ['No', 'No'],
#  8778510: ['Down', 'Steady'],
#  45144: ['Steady',
#   'Steady',
#   'Steady',
#   'Steady',
#   'Down',
#   'Steady',
#   'Steady',
#   'Steady',
#   'Steady'],
#  352377: ['Steady', 'No', 'Steady'],
#  3186981: ['Down'],
#  22757895: ['Steady'],
#  55479555: ['Steady'],
#  470754: ['Down'],
#  1101294: ['No'],
#  3467412: ['Steady', 'Steady', 'Steady'],
#  9025047: ['Steady'],
#  9029196: ['Steady'],
#  70269183: ['Steady', 'Down'],
#  5047470: ['No'],
#  686988: ['No', 'No'],
#  28766817: ['Down'],
#  76959585: ['Up', 'Steady'],
#  4571388: ['Down'],
#  2892654: ['Steady', 'Steady', 'Down', 'Steady', 'Steady', 'Steady'],
#  1422432: ['Down'],
#  8039988: ['Steady'],
#  111555: ['Steady'],
#  5193639: ['Up'],
#  1502829: ['Steady'],
#  522342: ['Steady', 'Steady', 'Steady'],
#  1957212: ['Steady'],
#  442782: ['Steady', 'Steady'],
#  6288831: ['Down'],
#  1606311: ['No'],
#  1791090: ['Steady', 'Steady', 'Steady'],
#  7443135: ['Steady'],
#  89177013: ['No'],
#  100510452: ['Steady'],
#  4765626: ['No', 'Steady', 'No', 'Steady'],
#  435366: ['No', 'No', 'Down', 'Steady', 'Steady', 'Down', 'Steady'],
#  707769: ['Down', 'No'],
#  73154043: ['Steady'],
#  4729023: ['No'],
#  3778047: ['No', 'Steady', 'Steady'],
#  2464146: ['Down'],
#  333252: ['No', 'No', 'No', 'No'],
#  2425617: ['No'],
#  86797872: ['Steady'],
#  4225995: ['Steady', 'No', 'No'],
#  8922573: ['Steady'],
#  60832998: ['Down'],
#  4065975: ['Steady', 'Steady', 'No', 'No'],
#  83120292: ['Up'],
#  688842: ['Steady'],
#  8035524: ['Up'],
#  719487: ['No', 'Steady'],
#  647181: ['No', 'No'],
#  687978: ['No', 'No'],
#  6884595: ['Steady',
#   'Steady',
#   'Down',
#   'Steady',
#   'Steady',
#   'Up',
#   'Steady',
#   'Steady',
#   'Steady',
#   'Steady'],
#  1426698: ['Down'],
#  2139525: ['No'],
#  99109602: ['No'],
#  27936: ['No'],
#  4696065: ['No'],
#  8308170: ['Steady'],
#  104789817: ['No'],
#  83898765: ['Steady'],
#  482958: ['No'],
#  6167682: ['Steady'],
#  4887171: ['No'],
#  99941634: ['Steady'],
#  55861758: ['Steady'],
#  9124884: ['Steady'],
#  5973228: ['Steady', 'No', 'Steady'],
#  1147545: ['Down'],
#  21943170: ['Down'],
#  1355697: ['No'],
#  5997636: ['No'],
#  2568312: ['Steady', 'Steady'],
#  3489048: ['Steady'],
#  886266: ['No'],
#  78398298: ['No'],
#  6035463: ['No'],
#  1734102: ['No', 'Steady', 'No', 'Steady', 'No', 'No'],
#  3344895: ['No', 'Steady', 'Steady', 'Down', 'Up', 'No'],
#  112077396: ['No'],
#  2029716: ['Steady'],
#  645309: ['No'],
#  1591542: ['No'],
#  289908: ['No'],
#  1159938: ['No'],
#  76024827: ['No'],
#  3252960: ['Steady', 'No'],
#  4161582: ['Steady', 'Steady'],
#  1524294: ['No', 'No'],
#  300825: ['No', 'No', 'No'],
#  105143886: ['Steady'],
#  952029: ['Steady'],
#  62473113: ['Steady'],
#  2241153: ['Steady', 'No', 'No', 'Steady', 'No'],
#  6564861: ['Steady'],
#  497439: ['Steady', 'No'],
#  331920: ['No'],
#  92948409: ['No'],
#  4118256: ['Steady'],
#  29952900: ['Steady'],
#  293967: ['No', 'No'],
#  3628350: ['Steady', 'Steady'],
#  8891883: ['No', 'Steady'],
#  5521167: ['Steady', 'No'],
#  2579661: ['Steady', 'Steady', 'Down', 'Steady'],
#  3538080: ['Steady',
#   'Steady',
#   'Steady',
#   'Up',
#   'No',
#   'Down',
#   'Down',
#   'No',
#   'Steady',
#   'Down'],
#  9037764: ['No'],
#  4173138: ['Steady'],
#  4065939: ['No'],
#  7986087: ['No'],
#  568098: ['Steady', 'Steady'],
#  3602925: ['No'],
#  4309191: ['No', 'No', 'No', 'No'],
#  1601532: ['Steady', 'Steady'],
#  2477079: ['Steady'],
#  76155741: ['Steady'],
#  52605: ['Down'],
#  1753524: ['Steady'],
#  50846004: ['Down'],
#  113423850: ['Down'],
#  106062624: ['Down'],
#  764316: ['Down'],
#  108477: ['Steady', 'Steady', 'No', 'No'],
#  4974165: ['Steady'],
#  910170: ['Down'],
#  2743047: ['Steady', 'Steady', 'Steady'],
#  9083610: ['Down', 'Up', 'Down', 'Up'],
#  1431603: ['No'],
#  1516860: ['Steady'],
#  26055648: ['No'],
#  1285902: ['No'],
#  407358: ['No', 'No', 'No'],
#  20733057: ['Up', 'Up'],
#  112367394: ['No'],
#  1125135: ['Down'],
#  1324764: ['No'],
#  7526574: ['Steady'],
#  6169482: ['Steady'],
#  767061: ['Steady', 'Up', 'Up'],
#  111516057: ['Steady'],
#  114960726: ['Steady'],
#  6290973: ['No'],
#  348984: ['No'],
#  104561757: ['No', 'Steady'],
#  1647585: ['Up'],
#  6458139: ['No'],
#  23031225: ['Steady', 'Down'],
#  109389519: ['Steady', 'Steady'],
#  74952: ['No', 'No', 'No', 'No', 'Steady', 'Steady', 'Steady'],
#  294273: ['No', 'No', 'No', 'No'],
#  97389531: ['Steady'],
#  5498046: ['No', 'Steady'],
#  757530: ['Steady'],
#  111501: ['No'],
#  24880779: ['Steady'],
#  4201875: ['Steady'],
#  73311894: ['Steady'],
#  5609844: ['No'],
#  113730309: ['No'],
#  8589357: ['No'],
#  355986: ['No'],
#  677412: ['Steady'],
#  9327402: ['No'],
#  5152140: ['No'],
#  693576: ['No', 'No'],
#  5150925: ['No', 'No'],
#  511047: ['No', 'No'],
#  533412: ['Steady'],
#  1690902: ['Steady'],
#  2526498: ['Steady', 'Up', 'Down', 'Down', 'No', 'Steady', 'Steady'],
#  23065767: ['Up'],
#  467208: ['Steady'],
#  97125948: ['Steady', 'Down'],
#  3862251: ['No', 'Up', 'Steady', 'Steady', 'Steady', 'Steady'],
#  13041: ['Up', 'Steady', 'Down', 'Down', 'No', 'Up', 'Steady', 'Steady'],
#  734211: ['Up'],
#  1332981: ['Steady', 'No', 'Steady', 'No'],
#  79956981: ['Up', 'Up'],
#  9213129: ['No'],
#  539685: ['Steady'],
#  1206027: ['Steady', 'No'],
#  45979002: ['Steady', 'Steady'],
#  4780035: ['No'],
#  4156794: ['No'],
#  6453342: ['Steady'],
#  1041291: ['Up', 'Steady'],
#  30800925: ['Steady'],
#  22829274: ['Steady'],
#  491643: ['No', 'Steady'],
#  105345450: ['Steady'],
#  6261003: ['No'],
#  6490224: ['No', 'No'],
#  4598280: ['Steady', 'Steady', 'Steady'],
#  1197414: ['Steady', 'No'],
#  2535174: ['Steady', 'Steady'],
#  89400861: ['Steady'],
#  2470770: ['No'],
#  313236: ['Steady', 'Steady'],
#  51738111: ['Up'],
#  70317027: ['Down'],
#  7783875: ['No', 'Steady'],
#  87840972: ['Down', 'Steady'],
#  3008313: ['No'],
#  9107163: ['No'],
#  4244877: ['Down'],
#  64511352: ['Steady'],
#  9395991: ['No', 'Steady'],
#  3240630: ['Down'],
#  7490601: ['Down', 'Down', 'Steady', 'Steady', 'Steady', 'Steady', 'Down'],
#  838854: ['No', 'No', 'Steady', 'No', 'Steady'],
#  5702373: ['Steady', 'No'],
#  64564002: ['Steady', 'Down'],
#  69973740: ['Steady'],
#  61462863: ['Up'],
#  67518999: ['No'],
#  38724426: ['Up'],
#  14515371: ['Down', 'Steady', 'Steady', 'Steady'],
#  5620536: ['No'],
#  2408922: ['No'],
#  36686808: ['No'],
#  830205: ['Steady'],
#  400500: ['Steady', 'Steady', 'Steady', 'Steady', 'Steady', 'Steady'],
#  5565897: ['Steady', 'No'],
#  633906: ['No',
#   'Steady',
#   'No',
#   'Steady',
#   'Steady',
#   'Up',
#   'Steady',
#   'Down',
#   'Up',
#   'Steady',
#   'Steady',
#   'Steady'],
#  6127722: ['No'],
#  2071701: ['Up'],
#  13320: ['Steady'],
#  463230: ['Steady', 'Steady'],
#  3397761: ['Steady', 'Steady'],
#  21689424: ['Steady', 'Steady'],
#  1723572: ['Up', 'Down', 'No'],
#  1697436: ['No', 'No', 'No'],
#  73286937: ['No'],
#  508824: ['No'],
#  87847776: ['No'],
#  92840139: ['Steady'],
#  102364812: ['No'],
#  59859657: ['Down', 'Down'],
#  6897267: ['No'],
#  7440732: ['No'],
#  9295110: ['Steady'],
#  23179356: ['Steady'],
#  4747986: ['No', 'Steady'],
#  2600469: ['Up'],
#  8760915: ['Steady'],
#  95439834: ['No'],
#  3217491: ['Steady'],
#  47412873: ['Steady'],
#  104752755: ['Down'],
#  3105513: ['No'],
#  3000240: ['No'],
#  348120: ['Down', 'No'],
#  3198834: ['Steady'],
#  65392893: ['Steady'],
#  74020698: ['Steady'],
#  439470: ['Down'],
#  66338397: ['No'],
#  22783734: ['Steady'],
#  3457683: ['Steady'],
#  13590: ['Steady'],
#  4472064: ['Steady'],
#  9416952: ['No'],
#  3381201: ['No'],
#  83268891: ['No'],
#  2020491: ['Steady'],
#  7308234: ['No', 'Steady'],
#  106706241: ['No'],
#  317934: ['No', 'Steady'],
#  27926721: ['Steady'],
#  67825269: ['Steady'],
#  8127882: ['Up'],
#  111353067: ['Steady'],
#  875979: ['Down', 'Steady'],
#  80019189: ['Steady'],
#  1941948: ['No'],
#  901332: ['Steady'],
#  56222487: ['Steady'],
#  2407023: ['No'],
#  42499845: ['Steady'],
#  98992197: ['Steady'],
#  35259498: ['Steady'],
#  1896381: ['No'],
#  389862: ['No'],
#  4103964: ['Steady',
#   'Down',
#   'No',
#   'Steady',
#   'Steady',
#   'Steady',
#   'Steady',
#   'Steady'],
#  5184918: ['Down'],
#  8325099: ['Steady', 'No'],
#  45703377: ['No'],
#  1054494: ['Steady'],
#  1665054: ['No', 'No', 'No', 'No', 'No', 'No', 'No', 'No'],
#  45655695: ['Down'],
#  76433292: ['Steady'],
#  69023016: ['Steady'],
#  3051027: ['Up'],
#  55111707: ['Steady'],
#  61162254: ['No'],
#  4951944: ['Steady'],
#  1061811: ['Down', 'Down', 'Steady', 'Steady', 'Steady'],
#  64052667: ['No'],
#  84595104: ['Steady', 'Steady', 'No'],
#  28982313: ['Steady'],
#  90056529: ['Up'],
#  65418831: ['Steady'],
#  91228698: ['Steady'],
#  4204035: ['Steady'],
#  3521574: ['No', 'No'],
#  60354486: ['No'],
#  5118912: ['Steady'],
#  96830199: ['Up'],
#  96901416: ['No'],
#  105956433: ['Steady'],
#  37044999: ['Steady', 'Steady'],
#  4420413: ['Steady', 'Steady', 'No', 'Steady', 'Steady'],
#  91292337: ['Steady'],
#  471951: ['Steady'],
#  68360337: ['Down'],
#  106656858: ['Up', 'Down'],
#  5027454: ['Steady'],
#  8605278: ['Steady'],
#  2970225: ['Steady', 'Steady'],
#  339651: ['Steady'],
#  93432348: ['Steady', 'Steady'],
#  76802157: ['Steady'],
#  4667985: ['Steady'],
#  206946: ['Down'],
#  113836635: ['Steady'],
#  3682530: ['Steady'],
#  6000192: ['Steady'],
#  89515035: ['No', 'Steady', 'No'],
#  109693890: ['No'],
#  4146147: ['Steady'],
#  96662457: ['No'],
#  1295469: ['Down', 'Down', 'Steady', 'Steady'],
#  27274527: ['No'],
#  21575907: ['Steady'],
#  62915535: ['Steady'],
#  77025807: ['No'],
#  4963419: ['No', 'No'],
#  9128817: ['Steady'],
#  798147: ['Steady'],
#  493911: ['No'],
#  2150901: ['Steady'],
#  7646184: ['Steady', 'Up'],
#  4235580: ['Steady'],
#  64603215: ['Steady'],
#  86572602: ['Steady', 'Steady', 'Down'],
#  93121191: ['No'],
#  109862649: ['Up'],
#  108580194: ['Up'],
#  81255195: ['Up', 'Steady', 'No', 'No', 'No', 'No', 'No'],
#  68622138: ['Up'],
#  5020047: ['Down'],
#  7596648: ['Steady'],
#  20676798: ['No'],
#  99530388: ['Up', 'Steady'],
#  2699316: ['No', 'No', 'Steady', 'Steady', 'Steady'],
#  6228999: ['Down'],
#  1917261: ['No'],
#  9900837: ['Steady'],
#  76825836: ['Steady'],
#  58136508: ['No'],
#  93520359: ['No', 'No'],
#  9196353: ['Steady'],
#  73088208: ['Up'],
#  41275089: ['Up'],
#  2656431: ['Steady'],
#  66656601: ['Steady'],
#  3611637: ['Steady'],
#  9394128: ['Steady'],
#  85118040: ['Down'],
#  704430: ['Steady'],
#  55632276: ['No'],
#  106312131: ['Steady'],
#  4837077: ['Steady', 'Steady', 'No', 'Steady', 'Steady'],
#  54452511: ['No'],
#  1550520: ['No', 'No'],
#  4910841: ['No'],
#  56464254: ['Down'],
#  9968661: ['No'],
#  103360833: ['Steady'],
#  2026161: ['Steady', 'Steady'],
#  1532520: ['Steady', 'Steady', 'Down', 'No', 'Steady', 'Steady', 'Steady'],
#  9264663: ['Steady'],
#  4867677: ['Steady', 'No'],
#  9343692: ['No'],
#  8208234: ['Down'],
#  5058702: ['No', 'No', 'Steady', 'Steady'],
#  726057: ['Down', 'Down'],
#  641007: ['No'],
#  894942: ['Steady', 'Steady'],
#  5984469: ['No', 'No', 'Steady'],
#  100955538: ['Down'],
#  111999186: ['Steady'],
#  54485127: ['Steady'],
#  1501533: ['No'],
#  4865508: ['Steady'],
#  77574114: ['Steady'],
#  689355: ['No'],
#  3480381: ['Steady'],
#  463302: ['Steady', 'Steady', 'Steady'],
#  9595107: ['Steady', 'Steady'],
#  443916: ['No', 'No', 'No'],
#  3179286: ['Steady'],
#  1686141: ['Steady'],
#  2836125: ['Down'],
#  1076481: ['Down'],
#  59648958: ['Steady'],
#  311418: ['Up', 'Up'],
#  5033565: ['No', 'No'],
#  2724075: ['No', 'Steady', 'No', 'No'],
#  3488049: ['No', 'No', 'No'],
#  10045584: ['Steady'],
#  1360332: ['No'],
#  92152944: ['Steady'],
#  1411479: ['Steady', 'No'],
#  1883097: ['Steady'],
#  4908897: ['Up'],
#  109816038: ['No'],
#  4327020: ['Up', 'Down'],
#  404289: ['No', 'Steady', 'No', 'No'],
#  2231748: ['No', 'No', 'No'],
#  4914693: ['No', 'Down', 'Steady', 'No'],
#  102190059: ['Steady'],
#  79024365: ['No'],
#  23076369: ['Up'],
#  97976430: ['No'],
#  2096937: ['Steady'],
#  9923850: ['Up'],
#  85853835: ['Steady'],
#  5875713: ['Steady'],
#  2791395: ['No'],
#  789876: ['Steady', 'No'],
#  52728858: ['Down'],
#  5833440: ['Down', 'Steady', 'Down'],
#  3184785: ['No'],
#  2742849: ['Down', 'Down', 'Down'],
#  5745888: ['No'],
#  328887: ['Steady',
#   'Steady',
#   'Steady',
#   'Steady',
#   'Steady',
#   'Steady',
#   'Steady',
#   'Steady'],
#  8509725: ['No', 'No', 'No'],
#  3357999: ['No'],
#  9961560: ['Steady'],
#  58871601: ['No'],
#  1395522: ['Steady', 'Steady', 'Steady', 'No'],
#  94784535: ['Down'],
#  338247: ['Steady', 'Steady', 'Down', 'Steady'],
#  9402138: ['No', 'Steady'],
#  41299119: ['Steady'],
#  791460: ['Steady', 'No'],
#  4250106: ['No', 'No'],
#  581499: ['No', 'No'],
#  9765999: ['No'],
#  4688325: ['Down'],
#  9998433: ['Down'],
#  97797942: ['Down'],
#  1681974: ['Down'],
#  10001988: ['Up'],
#  7422984: ['Steady', 'Down'],
#  10152693: ['Down'],
#  5128785: ['No', 'Steady', 'No', 'No'],
#  1427859: ['No'],
#  1126458: ['Steady'],
#  448839: ['Up', 'Steady'],
#  315684: ['No'],
#  5105286: ['No'],
#  10187370: ['Steady'],
#  4668507: ['Down'],
#  1529712: ['Steady'],
#  114194385: ['Down'],
#  1598733: ['No', 'No', 'No', 'No'],
#  398358: ['No'],
#  1215324: ['No'],
#  3362949: ['Steady'],
#  60974532: ['Up'],
#  772065: ['Steady', 'Steady'],
#  56993832: ['No'],
#  3030309: ['Steady', 'No', 'No', 'Steady'],
#  99756: ['No'],
#  65013930: ['Steady'],
#  36413037: ['Steady'],
#  318501: ['Steady', 'Steady', 'Up', 'Steady'],
#  639675: ['Steady'],
#  3039678: ['Steady', 'Steady'],
#  50124213: ['Steady'],
#  308727: ['No'],
#  3306690: ['Steady'],
#  3759597: ['No', 'No', 'No', 'Steady', 'No', 'Up'],
#  1777680: ['No'],
#  1455480: ['Down'],
#  113286348: ['Down'],
#  296622: ['No'],
#  1553643: ['No'],
#  3546306: ['No'],
#  106677: ['No', 'No', 'No'],
#  6270498: ['Down'],
#  11605212: ['Steady'],
#  56056428: ['Steady'],
#  2486826: ['Steady',
#   'No',
#   'Steady',
#   'Steady',
#   'Steady',
#   'Down',
#   'Down',
#   'Steady'],
#  760932: ['No', 'No'],
#  1234845: ['No'],
#  94626414: ['Steady'],
#  4993056: ['No'],
#  114767910: ['Down'],
#  3616155: ['Steady', 'Steady', 'Steady', 'Steady'],
#  1070622: ['Steady'],
#  23165379: ['Steady', 'Steady'],
#  4792239: ['Down', 'No'],
#  2766582: ['No'],
#  4282317: ['No'],
#  94527: ['No', 'Steady'],
#  2636928: ['Up'],
#  6150186: ['Steady'],
#  62619003: ['Steady'],
#  9946782: ['No', 'Steady'],
#  2601504: ['Up', 'No', 'Steady', 'Steady', 'Steady', 'Up'],
#  4768929: ['Up'],
#  60201873: ['Up'],
#  10171602: ['No'],
#  3210228: ['Steady'],
#  16621686: ['Steady'],
#  377964: ['Steady'],
#  4571586: ['Steady'],
#  6665103: ['No'],
#  103690143: ['Steady'],
#  10306782: ['No'],
#  79730316: ['Steady'],
#  1028106: ['No'],
#  15210: ['No'],
#  5686857: ['No'],
#  102101652: ['Steady'],
#  102099312: ['Down'],
#  55256283: ['No'],
#  3291489: ['No'],
#  334854: ['Steady'],
#  48070035: ['No'],
#  1766367: ['Steady'],
#  2611548: ['Down', 'Down'],
#  958833: ['No'],
#  45998793: ['Down'],
#  884952: ['Steady', 'Down', 'No', 'No', 'No'],
#  5924988: ['No', 'No'],
#  466524: ['No', 'No'],
#  522036: ['Steady'],
#  3444903: ['Steady', 'Up'],
#  618327: ['Steady', 'No'],
#  35740404: ['No', 'No'],
#  456696: ['No', 'Up'],
#  3697362: ['Steady', 'Steady'],
#  2523798: ['Down', 'No'],
#  3685653: ['Up'],
#  5662800: ['No', 'No'],
#  2344887: ['Up', 'No'],
#  4310694: ['No'],
#  2071863: ['Down', 'Steady', 'Steady', 'Steady'],
#  745443: ['No', 'Steady', 'Steady'],
#  1149777: ['No'],
#  61425855: ['Steady'],
#  9295857: ['Steady', 'No'],
#  5043762: ['No', 'No', 'Steady'],
#  51672654: ['Steady'],
#  46993104: ['Steady'],
#  1734912: ['Steady'],
#  469692: ['No', 'Steady', 'Steady', 'Steady', 'No', 'No'],
#  820035: ['No', 'No', 'No'],
#  634293: ['Steady'],
#  75593475: ['Up'],
#  2490849: ['Steady', 'Steady', 'Steady', 'Steady', 'Steady'],
#  106622244: ['Up'],
#  ...}
